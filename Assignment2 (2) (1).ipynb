# %%
import pandas as pd

# %%
df = pd.read_csv("air_data.csv")

# %%
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month   Day
# 0           NaN    NaN      NaN   NaN   NaN    NaN   NaN
# 1           1.0   41.0    190.0   7.4  67.0    5.0   1.0
# 2           2.0   36.0    118.0   8.0  72.0    5.0   2.0
# 3           3.0   12.0    149.0  12.6  74.0    5.0   3.0
# 4           4.0   18.0    313.0  11.5  62.0    5.0   4.0
# ..          ...    ...      ...   ...   ...    ...   ...
# 105       105.0   28.0    273.0  11.5  82.0    8.0  13.0
# 106       106.0   65.0    157.0   9.7  80.0    8.0  14.0
# 107       107.0    NaN     64.0  11.5  79.0    8.0  15.0
# 108       108.0   22.0     71.0  10.3  77.0    8.0  16.0
# 109         NaN    NaN      NaN   NaN   NaN    NaN   NaN
#
# [110 rows x 7 columns]

# %%
df.shape
# Out:
# (110, 7)

# %%
df.dtypes
# Out:
# Unnamed: 0    float64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp          float64
# Month         float64
# Day           float64
# dtype: object

# %%
df = df.drop([0,109])

# %%
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month   Day
# 1           1.0   41.0    190.0   7.4  67.0    5.0   1.0
# 2           2.0   36.0    118.0   8.0  72.0    5.0   2.0
# 3           3.0   12.0    149.0  12.6  74.0    5.0   3.0
# 4           4.0   18.0    313.0  11.5  62.0    5.0   4.0
# 5           5.0    NaN      NaN  14.3  56.0    5.0   5.0
# ..          ...    ...      ...   ...   ...    ...   ...
# 104       104.0   44.0    192.0  11.5  86.0    8.0  12.0
# 105       105.0   28.0    273.0  11.5  82.0    8.0  13.0
# 106       106.0   65.0    157.0   9.7  80.0    8.0  14.0
# 107       107.0    NaN     64.0  11.5  79.0    8.0  15.0
# 108       108.0   22.0     71.0  10.3  77.0    8.0  16.0
#
# [108 rows x 7 columns]

# %%
df = df.drop("Unnamed: 0",axis=1)

# %%
df
# Out:
#      Ozone  Solar.R  Wind  Temp  Month   Day
# 1     41.0    190.0   7.4  67.0    5.0   1.0
# 2     36.0    118.0   8.0  72.0    5.0   2.0
# 3     12.0    149.0  12.6  74.0    5.0   3.0
# 4     18.0    313.0  11.5  62.0    5.0   4.0
# 5      NaN      NaN  14.3  56.0    5.0   5.0
# ..     ...      ...   ...   ...    ...   ...
# 104   44.0    192.0  11.5  86.0    8.0  12.0
# 105   28.0    273.0  11.5  82.0    8.0  13.0
# 106   65.0    157.0   9.7  80.0    8.0  14.0
# 107    NaN     64.0  11.5  79.0    8.0  15.0
# 108   22.0     71.0  10.3  77.0    8.0  16.0
#
# [108 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Ozone      34
# Solar.R     7
# Wind        0
# Temp        0
# Month       0
# Day         0
# dtype: int64

# %%
df=df.fillna(value={"Ozone":df["Ozone"].mean(),"Solar.R":df["Solar.R"].mean()})

# %%
df
# Out:
#          Ozone     Solar.R  Wind  Temp  Month   Day
# 1    41.000000  190.000000   7.4  67.0    5.0   1.0
# 2    36.000000  118.000000   8.0  72.0    5.0   2.0
# 3    12.000000  149.000000  12.6  74.0    5.0   3.0
# 4    18.000000  313.000000  11.5  62.0    5.0   4.0
# 5    42.418919  191.108911  14.3  56.0    5.0   5.0
# ..         ...         ...   ...   ...    ...   ...
# 104  44.000000  192.000000  11.5  86.0    8.0  12.0
# 105  28.000000  273.000000  11.5  82.0    8.0  13.0
# 106  65.000000  157.000000   9.7  80.0    8.0  14.0
# 107  42.418919   64.000000  11.5  79.0    8.0  15.0
# 108  22.000000   71.000000  10.3  77.0    8.0  16.0
#
# [108 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Ozone      0
# Solar.R    0
# Wind       0
# Temp       0
# Month      0
# Day        0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.scatterplot(data=df,x="Ozone",y="Wind",hue="Month")
# Out:
# <Axes: xlabel='Ozone', ylabel='Wind'>

# %%
sns.scatterplot(data=df,x="Ozone",y="Temp",hue="Month")
# Out:
# <Axes: xlabel='Ozone', ylabel='Temp'>

# %%
sns.scatterplot(data=df,x="Ozone",y="Solar.R",hue="Month")
# Out:
# <Axes: xlabel='Ozone', ylabel='Solar.R'>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20, 14))
sns.boxplot(data=df,x="Month",y="Ozone")
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(20, 14))
sns.boxplot(data=df,x="Day",y="Ozone")
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(20, 14))
sns.boxplot(data=df,x="Temp",y="Ozone")
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(20, 14))
sns.barplot(data=df,x="Temp",y="Ozone")
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(20, 14))
sns.barplot(data=df,x="Wind",y="Ozone")
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(20, 14))
sns.barplot(data=df,x="Day",y="Ozone")
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(20, 14))
sns.histplot(data=df,x="Wind")
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(20, 14))
sns.histplot(data=df,x="Solar.R",kde=True)
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(20, 14))
sns.histplot(data=df,x="Ozone",hue="Month",palette="deep")
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(20, 14))
sns.displot(data=df,x="Wind",kind="kde")
plt.plot()
# Out:
# []

# %%
count=df["Month"].value_counts()
plt.pie(count,labels=count.index,autopct='%.1f%%')
plt.show()

# %%
plt.figure(figsize=(20, 14))
count=df["Ozone"].value_counts()
plt.pie(count,labels=count.index,autopct='%.1f%%')
plt.show()

# %%
plt.figure(figsize=(20, 14))
count=df["Wind"].value_counts()
plt.pie(count,labels=count.index,autopct='%.1f%%')
plt.show()

# %%
df.corr()
# Out:
#             Ozone   Solar.R      Wind      Temp     Month       Day
# Ozone    1.000000  0.325547 -0.463648  0.572369  0.425781 -0.021795
# Solar.R  0.325547  1.000000 -0.048794  0.289614  0.006278 -0.168179
# Wind    -0.463648 -0.048794  1.000000 -0.401515 -0.302494  0.030999
# Temp     0.572369  0.289614 -0.401515  1.000000  0.735921 -0.146081
# Month    0.425781  0.006278 -0.302494  0.735921  1.000000 -0.203542
# Day     -0.021795 -0.168179  0.030999 -0.146081 -0.203542  1.000000

# %%
sns.heatmap(df.corr(), annot=True)
plt.plot()
# Out:
# []

# %%
X = df[["Temp"]]

# %%
Y = df["Ozone"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y)

# %%
X_train
# Out:
#     Temp
# 38  82.0
# 71  89.0
# 23  61.0
# 73  73.0
# 40  90.0
# ..   ...
# 6   66.0
# 68  88.0
# 28  67.0
# 48  72.0
# 8   59.0
#
# [81 rows x 1 columns]

# %%
Y_train
# Out:
# 38    29.0
# 71    85.0
# 23     4.0
# 73    10.0
# 40    71.0
#       ...
# 6     28.0
# 68    77.0
# 28    23.0
# 48    37.0
# 8     19.0
# Name: Ozone, Length: 81, dtype: float64

# %%
X_test
# Out:
#      Temp
# 94   81.0
# 67   83.0
# 41   87.0
# 20   62.0
# 49   65.0
# 75   91.0
# 35   84.0
# 85   86.0
# 22   73.0
# 88   86.0
# 15   58.0
# 101  90.0
# 46   79.0
# 76   80.0
# 31   76.0
# 42   93.0
# 52   77.0
# 54   76.0
# 66   83.0
# 79   84.0
# 4    62.0
# 24   61.0
# 89   88.0
# 62   84.0
# 2    72.0
# 61   83.0
# 64   81.0

# %%
Y_test
# Out:
# 94       9.000000
# 67      40.000000
# 41      39.000000
# 20      11.000000
# 49      20.000000
# 75      42.418919
# 35      42.418919
# 85      80.000000
# 22      11.000000
# 88      52.000000
# 15      18.000000
# 101    110.000000
# 46      42.418919
# 76       7.000000
# 31      37.000000
# 42      42.418919
# 52      42.418919
# 54      42.418919
# 66      64.000000
# 79      61.000000
# 4       18.000000
# 24      32.000000
# 89      82.000000
# 62     135.000000
# 2       36.000000
# 61      42.418919
# 64      32.000000
# Name: Ozone, dtype: float64

# %%
from sklearn import linear_model

# %%
regr = linear_model.LinearRegression()

# %%
regr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
regr.predict(X_test)
# Out:
# array([48.06684896, 51.14393737, 57.29811419, 18.83450907, 23.45014168,
#        63.45229101, 52.68248158, 55.75956999, 35.75849532, 55.75956999,
#        12.68033225, 61.91374681, 44.98976055, 46.52830476, 40.37412794,
#        66.52937942, 41.91267214, 40.37412794, 51.14393737, 52.68248158,
#        18.83450907, 17.29596486, 58.8366584 , 52.68248158, 34.21995112,
#        51.14393737, 48.06684896])

# %%
pred=regr.predict(X_test)

# %%
from sklearn import metrics

# %%
metrics.mean_squared_error(Y_test,pred)
# Out:
# 608.4927964776753

# %%
import numpy as np
np.sqrt(metrics.mean_squared_error(Y_test,Y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 2
#       1 import numpy as np
# ----> 2 np.sqrt(metrics.mean_squared_error(Y_test,Y_pred))
#
# NameError: name 'Y_pred' is not defined

# %%
metrics.mean_absolute_error(Y_test,pred)

# %%
metrics.r2_score(Y_test,pred)

# %%
sns.regplot(data=df,x="Temp",y="Ozone")

# %%
d1 = pd.DataFrame({"Temp":[72]})

# %%
print(regr.predict(d1))

# %%
X1=df[["Solar.R","Wind","Temp"]]

# %%
Y1=df["Ozone"]

# %%
X1_train,X1_test,Y1_train,Y1_test=train_test_split(X1,Y1)

# %%
regr1 = linear_model.LinearRegression()

# %%
regr1.fit(X1_train,Y1_train)

# %%
regr1.predict(X1_test)

# %%
pred1=regr1.predict(X1_test)

# %%
metrics.mean_squared_error(Y1_test,pred1)

# %%
metrics.mean_absolute_error(Y1_test,pred1)

# %%
metrics.r2_score(Y1_test,pred1)

# %%
d2 = pd.DataFrame({"Solar.R":[190],
                   "Wind":[7.4],
                   "Temp":[67]})

# %%
regr1.predict(d2)
