# %%
import pandas as pd
data1 = pd.read_csv("data1.csv")

# %%
data1
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
data1.head(9)
# Out:
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000   7420         4          2        3      yes        no       no
# 1  12250000   8960         4          4        4      yes        no       no
# 2  12250000   9960         3          2        2      yes        no      yes
# 3  12215000   7500         4          2        2      yes        no      yes
# 4  11410000   7420         4          1        2      yes       yes      yes
# 5  10850000   7500         3          3        1      yes        no      yes
# 6  10150000   8580         4          3        4      yes        no       no
# 7  10150000  16200         5          3        2      yes        no       no
# 8   9870000   8100         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# ...

# %%
data1.tail(9)
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 536  1960000  3420         5          1        2       no        no       no
# 537  1890000  1700         3          1        2      yes        no       no
# 538  1890000  3649         2          1        1      yes        no       no
# 539  1855000  2990         2          1        1       no        no       no
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 536              no              no        0       no      unfurnished
# ...

# %%
data1.dtypes
# Out:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# prefarea            object
# furnishingstatus    object
# dtype: object

# %%
data1.shape
# Out:
# (545, 13)

# %%
data1==0
# Out:
#      price   area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    False  False     False      False    False     False      False
# 1    False  False     False      False    False     False      False
# 2    False  False     False      False    False     False      False
# 3    False  False     False      False    False     False      False
# 4    False  False     False      False    False     False      False
# ..     ...    ...       ...        ...      ...       ...        ...
# 540  False  False     False      False    False     False      False
# 541  False  False     False      False    False     False      False
# 542  False  False     False      False    False     False      False
# 543  False  False     False      False    False     False      False
# 544  False  False     False      False    False     False      False
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0       False            False            False    False     False
# ...

# %%
data1[data1==0].count()
# Out:
# price                 0
# area                  0
# bedrooms              0
# bathrooms             0
# stories               0
# mainroad              0
# guestroom             0
# basement              0
# hotwaterheating       0
# airconditioning       0
# parking             299
# prefarea              0
# furnishingstatus      0
# dtype: int64

# %%
data1.isna()
# Out:
#      price   area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    False  False     False      False    False     False      False
# 1    False  False     False      False    False     False      False
# 2    False  False     False      False    False     False      False
# 3    False  False     False      False    False     False      False
# 4    False  False     False      False    False     False      False
# ..     ...    ...       ...        ...      ...       ...        ...
# 540  False  False     False      False    False     False      False
# 541  False  False     False      False    False     False      False
# 542  False  False     False      False    False     False      False
# 543  False  False     False      False    False     False      False
# 544  False  False     False      False    False     False      False
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0       False            False            False    False     False
# ...

# %%
data1[data1.isna()].count()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
data1.mean()
# Out:
# <ipython-input-14-3ea1a6dabdbd>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data1.mean()
# price        4.766729e+06
# area         5.150541e+03
# bedrooms     2.965138e+00
# bathrooms    1.286239e+00
# stories      1.805505e+00
# parking      6.935780e-01
# dtype: float64

# %%
data1.mean(numeric_only=True)
# Out:
# price        4.766729e+06
# area         5.150541e+03
# bedrooms     2.965138e+00
# bathrooms    1.286239e+00
# stories      1.805505e+00
# parking      6.935780e-01
# dtype: float64

# %%
training = data1[["price","area","bedrooms","bathrooms","stories","mainroad","guestroom","basement","hotwaterheating","airconditioning","parking","furnishingstatus"]]

# %%
training
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
training.iloc[:99,[0,1,2,4,6,9,10,11]]
# Out:
#        price  area  bedrooms  stories guestroom airconditioning  parking  \
# 0   13300000  7420         4        3        no             yes        2
# 1   12250000  8960         4        4        no             yes        3
# 2   12250000  9960         3        2        no              no        2
# 3   12215000  7500         4        2        no             yes        3
# 4   11410000  7420         4        2       yes             yes        2
# ..       ...   ...       ...      ...       ...             ...      ...
# 94   6300000  6000         4        4        no              no        1
# 95   6300000  4100         3        3        no             yes        2
# 96   6300000  9000         3        1        no              no        1
# 97   6300000  6400         3        1       yes             yes        1
# 98   6293000  6600         3        3        no             yes        0
#
#    furnishingstatus
# 0         furnished
# 1         furnished
# 2    semi-furnished
# ...

# %%
training.iloc[:545,[1,3,5,7,9]]
# Out:
#      area  bathrooms mainroad basement airconditioning
# 0    7420          2      yes       no             yes
# 1    8960          4      yes       no             yes
# 2    9960          2      yes      yes              no
# 3    7500          2      yes      yes             yes
# 4    7420          1      yes      yes             yes
# ..    ...        ...      ...      ...             ...
# 540  3000          1      yes      yes              no
# 541  2400          1       no       no              no
# 542  3620          1      yes       no              no
# 543  2910          1       no       no              no
# 544  3850          1      yes       no              no
#
# [545 rows x 5 columns]

# %%
data2 = data1[data1["furnishingstatus"] == "furnished"]

# %%
data2
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# 8     9870000  8100         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 509   2590000  3600         2          2        2      yes        no      yes
# 512   2520000  3000         2          1        2      yes        no       no
# 522   2380000  2475         3          1        2      yes        no       no
# 523   2380000  2787         4          2        2      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
#
# ...

# %%
import numpy as np

# %%
from sklearn.model_selection import train_test_split

# %%
X = data1[["area","bedrooms","stories","guestroom","airconditioning","parking","furnishingstatus"]]

# %%
Y = data1[["price"]]

# %%
X
# Out:
#      area  bedrooms  stories guestroom airconditioning  parking  \
# 0    7420         4        3        no             yes        2
# 1    8960         4        4        no             yes        3
# 2    9960         3        2        no              no        2
# 3    7500         4        2        no             yes        3
# 4    7420         4        2       yes             yes        2
# ..    ...       ...      ...       ...             ...      ...
# 540  3000         2        1        no              no        2
# 541  2400         3        1        no              no        0
# 542  3620         2        1        no              no        0
# 543  2910         3        1        no              no        0
# 544  3850         3        2        no              no        0
#
#     furnishingstatus
# 0          furnished
# 1          furnished
# 2     semi-furnished
# 3          furnished
# 4          furnished
# ..               ...
# 540      unfurnished
# ...

# %%
Y
# Out:
#         price
# 0    13300000
# 1    12250000
# 2    12250000
# 3    12215000
# 4    11410000
# ..        ...
# 540   1820000
# 541   1767150
# 542   1750000
# 543   1750000
# 544   1750000
#
# [545 rows x 1 columns]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,random_state=0,test_size=0.25)

# %%
X_train
# Out:
#       area  bedrooms  stories guestroom airconditioning  parking  \
# 498   2000         2        2        no              no        0
# 531   5300         3        1        no             yes        0
# 532   3000         2        1        no              no        0
# 278   3400         3        2        no              no        2
# 101   5500         3        3        no              no        1
# ..     ...       ...      ...       ...             ...      ...
# 70    4000         3        2        no             yes        0
# 277  10360         2        1        no              no        1
# 9     5750         3        4       yes             yes        1
# 359   3600         3        1        no              no        1
# 192   6600         3        1       yes              no        0
#
#     furnishingstatus
# 498   semi-furnished
# 531      unfurnished
# 532      unfurnished
# 278   semi-furnished
# 101      unfurnished
# ..               ...
# 70    semi-furnished
# ...

# %%
Y_train
# Out:
#        price
# 498  2660000
# 531  2233000
# 532  2135000
# 278  4277000
# 101  6230000
# ..       ...
# 70   6790000
# 277  4305000
# 9    9800000
# 359  3710000
# 192  5040000
#
# [408 rows x 1 columns]

# %%
X_test
# Out:
#       area  bedrooms  stories guestroom airconditioning  parking  \
# 239   4000         3        2        no              no        1
# 113   9620         3        1        no              no        2
# 325   3460         4        2        no             yes        0
# 66   13200         2        1        no              no        1
# 479   3660         4        2        no              no        0
# ..     ...       ...      ...       ...             ...      ...
# 319   3000         4        3        no             yes        2
# 525   3640         2        1        no              no        0
# 245   5360         3        2        no              no        2
# 7    16200         5        2        no              no        0
# 375   5960         3        2       yes              no        0
#
#     furnishingstatus
# 239        furnished
# 113        furnished
# 325   semi-furnished
# 66         furnished
# 479      unfurnished
# ..               ...
# 319   semi-furnished
# ...

# %%
Y_test
# Out:
#         price
# 239   4585000
# 113   6083000
# 325   4007500
# 66    6930000
# 479   2940000
# ..        ...
# 319   4060000
# 525   2345000
# 245   4550000
# 7    10150000
# 375   3640000
#
# [137 rows x 1 columns]

# %%
X_train.shape
# Out:
# (408, 7)

# %%
Y_train.shape
# Out:
# (408, 1)

# %%
X_test.shape
# Out:
# (137, 7)

# %%
Y_test.shape
# Out:
# (137, 1)

# %%
import pandas as pd
import seaborn as sns

# %%
sns.pairplot(data1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sns.pairplot(data1)
#
# NameError: name 'data1' is not defined

# %%
sns.pairplot(data1,hue="furnishingstatus")

# %%
sns.pairplot(data1,hue="bedrooms")
